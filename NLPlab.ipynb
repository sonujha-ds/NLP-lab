# %%
# !pip install pandas numpy request beautifulsoup4
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement request (from versions: none)
# ERROR: No matching distribution found for request

# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
# !pip install bs4

# %%
link="https://www.geeksforgeeks.org/courses?_gl=1*ujj1ht*_up*MQ..*_gs*MQ..&gclid=EAIaIQobChMImMGI666ulgMVrplmAh3seCc3EAAYASAAEgJf8vD_BwE&gbraid=0AAAAAC9yBkAVdxzM7biCG8tInrgQu8xND"
data= requests.get(link)
print(data.status_code)
# Out:
# 200

# %%
#headers
headers= {"User-Agent": "Mozilla/5.0"}
data2= requests.get(link, headers=headers)
print(data2.status_code)
# Out:
# 200

# %%
data.text
# Out:
# '<!DOCTYPE html><html lang="en"><head><link rel="canonical" href="https://www.geeksforgeeks.org/courses"/><link href="https://assets.geeksforgeeks.org/semantic-ui/2.4.1/semantic.min.css" rel="stylesheet" media="all"/><script type="application/ld+json">{"@context":"https://schema.org","@type":"ItemList","name":"GeeksforGeeks Courses","itemListElement":[{"@type":"ListItem","position":1,"item":{"@type":"Course","url":"https://www.geeksforgeeks.org/courses/placement-360-cip-complete-tech-interview","name":"Placement 360 Course - Complete Tech Interview Prep","description":"Master Programming, DSA, Low-Level Design, SQL, Core CS Subjects, and AptitudeLearn through premium self-paced video lessons, coding problems, and mock assessmentsBuild strong coding, problem-solving, software design, and interview skillsBecome interview-ready for top tech companies like Google, Amazon, Microsoft, Adobe, and Flipkart","image":["https://media.geeksforgeeks.org/img-practice/prod/courses/1/Web/Header/Plac
# ...

# %%
# !pip install lxml

# %%
soup = BeautifulSoup(data.text,'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://www.geeksforgeeks.org/courses" rel="canonical"/>
#   <link href="https://assets.geeksforgeeks.org/semantic-ui/2.4.1/semantic.min.css" media="all" rel="stylesheet"/>
#   <script type="application/ld+json">
# ...

# %%
# !pip install parser
# Out:
# ERROR: Could not find a version that satisfies the requirement parser (from versions: none)
# ERROR: No matching distribution found for parser

# %%
soup = BeautifulSoup(data.text, 'html.parser')

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(data.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://www.geeksforgeeks.org/courses" rel="canonical"/>
#   <link href="https://assets.geeksforgeeks.org/semantic-ui/2.4.1/semantic.min.css" media="all" rel="stylesheet"/>
#   <script type="application/ld+json">
# ...

# %%
soup.find_all("h1")
# Out:
# [<h1 class="ui header sofia-pro courseListingPage_headerTitle__zyNWE">GeeksforGeeks Courses</h1>]

# %%
soup.find_all("h1")[0]
# Out:
# <h1 class="ui header sofia-pro courseListingPage_headerTitle__zyNWE">GeeksforGeeks Courses</h1>

# %%
soup.find_all("h1")[0].text
# Out:
# 'GeeksforGeeks Courses'

# %%
soup.find_all("h4")
# Out:
# [<h4 class="ui left aligned header courseListingPage_myAuto__i6GdI sofia-pro course_heading">Placement 360 Course - Complete Tech Interview Prep</h4>,
#  <h4 class="ui left aligned header courseListingPage_myAuto__i6GdI sofia-pro course_heading">Data Science 360 Course - Data Analytics, ML &amp; AI</h4>,
#  <h4 class="ui left aligned header courseListingPage_myAuto__i6GdI sofia-pro course_heading">DevOps &amp; Cloud Course - AWS, Docker, Kubernetes with AI</h4>,
#  <h4 class="ui left aligned header courseListingPage_myAuto__i6GdI sofia-pro course_heading">AI Engineering Course - Generative AI &amp; Agentic AI</h4>,
#  <h4 class="ui left aligned header courseListingPage_myAuto__i6GdI sofia-pro course_heading">MERN Full Stack Course - React, Node &amp; MongoDB with AI</h4>,
#  <h4 class="ui left aligned header courseListingPage_myAuto__i6GdI sofia-pro course_heading">DSA &amp; System Design Course - SDE Interview Prep</h4>,
# ...

# %%
for i in soup.find_all("h4"):
    print(i.text)
# Out:
# Placement 360 Course - Complete Tech Interview Prep
# Data Science 360 Course - Data Analytics, ML & AI
# DevOps & Cloud Course - AWS, Docker, Kubernetes with AI
# AI Engineering Course - Generative AI & Agentic AI
# MERN Full Stack Course - React, Node & MongoDB with AI
# DSA & System Design Course - SDE Interview Prep
# Java Backend Course - Spring Boot, Microservices with AI
# System Design Course - HLD, Scalability & Distributed Systems

# %%
headings=[]
for i in soup.find_all("h4"):
    headings.append(i.text)
    
headings
# Out:
# ['Placement 360 Course - Complete Tech Interview Prep',
#  'Data Science 360 Course - Data Analytics, ML & AI',
#  'DevOps & Cloud Course - AWS, Docker, Kubernetes with AI',
#  'AI Engineering Course - Generative AI & Agentic AI',
#  'MERN Full Stack Course - React, Node & MongoDB with AI',
#  'DSA & System Design Course - SDE Interview Prep',
#  'Java Backend Course - Spring Boot, Microservices with AI',
#  'System Design Course - HLD, Scalability & Distributed Systems']

# %%
for i in soup.find_all('div', class_="courseListingPage_priceTags__PXTc9"):
    print(i.text)
# Out:
# ₹ 6999₹ 9999
# ₹ 7999₹ 12999
# ₹ 17999₹ 25699
# ₹ 19999₹ 28599
# ₹ 7999₹ 12999
# ₹ 14999₹ 29999
# ₹ 14999₹ 23999
# ₹ 14999₹ 23999

# %%
for i in soup.find_all('div', class_="courseListingPage_priceTags__PXTc9"):
    print(i.text.split('₹'))
# Out:
# ['', ' 6999', ' 9999']
# ['', ' 7999', ' 12999']
# ['', ' 17999', ' 25699']
# ['', ' 19999', ' 28599']
# ['', ' 7999', ' 12999']
# ['', ' 14999', ' 29999']
# ['', ' 14999', ' 23999']
# ['', ' 14999', ' 23999']

# %%
disc_price=[]
org_price=[]
for i in soup.find_all('div', class_="courseListingPage_priceTags__PXTc9"):
    disc_price.append(i.text.split('₹')[1])
    
disc_price
# Out:
# [' 6999', ' 7999', ' 17999', ' 19999', ' 7999', ' 14999', ' 14999', ' 14999']

# %%
for i in soup.find_all('div', class_="courseListingPage_priceTags__PXTc9"):
    org_price.append(i.text.split('₹')[2])
org_price
# Out:
# [' 9999', ' 12999', ' 25699', ' 28599', ' 12999', ' 29999', ' 23999', ' 23999']

# %%
soup.find_all('img', alt="course thumbnail")
# Out:
# [<img alt="course thumbnail" src="https://media.geeksforgeeks.org/img-practice/prod/courses/1/Web/Header/Placement360-thumbnail_1783596310.webp"/>,
#  <img alt="course thumbnail" src="https://media.geeksforgeeks.org/wp-content/uploads/20260908175723511835/data-science.webp"/>,
#  <img alt="course thumbnail" src="https://media.geeksforgeeks.org/wp-content/uploads/20260908175723704399/devops.webp"/>,
#  <img alt="course thumbnail" src="https://media.geeksforgeeks.org/wp-content/uploads/20260908175723092081/ai-engineering.webp"/>,
#  <img alt="course thumbnail" src="https://media.geeksforgeeks.org/wp-content/uploads/20260908175724379406/mern.webp"/>,
#  <img alt="course thumbnail" src="https://media.geeksforgeeks.org/wp-content/uploads/20260908175723905660/dsa-system-design.webp"/>,
#  <img alt="course thumbnail" src="https://media.geeksforgeeks.org/wp-content/uploads/20260908175724180292/java-backend.webp"/>,
# ...

# %%
img=[]
for i in soup.find_all('img', alt="course thumbnail"):
    img.append(i.get('src'))
img
# Out:
# ['https://media.geeksforgeeks.org/img-practice/prod/courses/1/Web/Header/Placement360-thumbnail_1783596310.webp',
#  'https://media.geeksforgeeks.org/wp-content/uploads/20260908175723511835/data-science.webp',
#  'https://media.geeksforgeeks.org/wp-content/uploads/20260908175723704399/devops.webp',
#  'https://media.geeksforgeeks.org/wp-content/uploads/20260908175723092081/ai-engineering.webp',
#  'https://media.geeksforgeeks.org/wp-content/uploads/20260908175724379406/mern.webp',
#  'https://media.geeksforgeeks.org/wp-content/uploads/20260908175723905660/dsa-system-design.webp',
#  'https://media.geeksforgeeks.org/wp-content/uploads/20260908175724180292/java-backend.webp',
#  'https://media.geeksforgeeks.org/wp-content/uploads/20260908175724844263/system-design.webp']

# %%
df=pd.DataFrame({"Name":headings,
                 "Thumb nail": img,
                 "Discount price": disc_price,
                 "Original price": org_price})
df
# Out:
#                                                 Name  \
# 0  Placement 360 Course - Complete Tech Interview...
# 1  Data Science 360 Course - Data Analytics, ML & AI
# 2  DevOps & Cloud Course - AWS, Docker, Kubernete...
# 3  AI Engineering Course - Generative AI & Agenti...
# 4  MERN Full Stack Course - React, Node & MongoDB...
# 5    DSA & System Design Course - SDE Interview Prep
# 6  Java Backend Course - Spring Boot, Microservic...
# 7  System Design Course - HLD, Scalability & Dist...
#
#                                           Thumb nail Discount price  \
# 0  https://media.geeksforgeeks.org/img-practice/p...           6999
# 1  https://media.geeksforgeeks.org/wp-content/upl...           7999
# 2  https://media.geeksforgeeks.org/wp-content/upl...          17999
# 3  https://media.geeksforgeeks.org/wp-content/upl...          19999
# 4  https://media.geeksforgeeks.org/wp-content/upl...           7999
# 5  https://media.geeksforgeeks.org/wp-content/upl...          14999
# ...

# %%
df.to_csv("nlp.csv", index=False)
